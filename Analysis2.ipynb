# %%
import pandas as pd
import matplotlib.pyplot as plt

import numpy as np

# %%
data_path = "/Users/yatingyang/Desktop/DSCI531/Project/recruitmentdataset-2022-1.3.csv"
df_data = pd.read_csv(data_path, delimiter=",")
df_data.head()
# Out:
#        Id  gender  age nationality     sport  ind-university_grade  \
# 0  x8011e  female   24      German  Swimming                    70
# 1  x6077a    male   26      German      Golf                    67
# 2  x6006e  female   23       Dutch   Running                    67
# 3  x2173b    male   24       Dutch   Cricket                    70
# 4  x6241a  female   26      German      Golf                    59
#
#    ind-debateclub  ind-programming_exp  ind-international_exp  \
# 0           False                False                  False
# 1           False                 True                  False
# 2           False                 True                   True
# 3           False                 True                  False
# 4           False                False                  False
#
#    ind-entrepeneur_exp  ind-languages  ind-exact_study ind-degree company  \
# 0                False              1             True        phd       A
# ...

# %%
# Hypothetically adding gender data to df_data
# For demonstration, let's assume this step has already been done and 'gender' column is added

# Filter data by gender
male_data = df_data[df_data['gender'] == 'male']
female_data = df_data[df_data['gender'] == 'female']

# Calculate acceptance rates for each gender with and without programming experience
prog_exp_yes_male = male_data[male_data['ind-programming_exp'] == True]['decision'].mean()
prog_exp_no_male = male_data[male_data['ind-programming_exp'] == False]['decision'].mean()

prog_exp_yes_female = female_data[female_data['ind-programming_exp'] == True]['decision'].mean()
prog_exp_no_female = female_data[female_data['ind-programming_exp'] == False]['decision'].mean()

# Data for plotting
labels = ['Programming Experience', 'No Programming Experience']
male_acceptance_rates = [prog_exp_yes_male, prog_exp_no_male]
female_acceptance_rates = [prog_exp_yes_female, prog_exp_no_female]

# Creating the bar graphs
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, male_acceptance_rates, width, label='Male', color='blue')
rects2 = ax.bar(x + width/2, female_acceptance_rates, width, label='Female', color='orange')

# Add some text for labels, title, and custom x-axis tick labels, etc.
ax.set_ylabel('Acceptance Rate')
ax.set_title('Acceptance Rate by Programming Experience and Gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

ax.set_ylim(0, 1.0)  # Ensuring the y-axis starts at 0 and ends at 1 for clarity

plt.show()

# %%
intl_exp_yes_male = male_data[male_data['ind-international_exp'] == True]['decision'].mean()
intl_exp_no_male = male_data[male_data['ind-international_exp'] == False]['decision'].mean()

intl_exp_yes_female = female_data[female_data['ind-international_exp'] == True]['decision'].mean()
intl_exp_no_female = female_data[female_data['ind-international_exp'] == False]['decision'].mean()

# Data for plotting
labels = ['International Experience', 'No International Experience']
male_acceptance_rates = [intl_exp_yes_male, intl_exp_no_male]
female_acceptance_rates = [intl_exp_yes_female, intl_exp_no_female]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, male_acceptance_rates, width, label='Male', color='blue')
rects2 = ax.bar(x + width/2, female_acceptance_rates, width, label='Female', color='pink')

# Add some text for labels, title, and custom x-axis tick labels, etc.
ax.set_ylabel('Acceptance Rate')
ax.set_title('Acceptance Rate by International Experience and Gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

ax.set_ylim(0, 1.0)  # Ensuring the y-axis starts at 0 and ends at 1 for clarity

plt.show()

# %%
ent_exp_yes_male = male_data[male_data['ind-entrepeneur_exp'] == True]['decision'].mean()
ent_exp_no_male = male_data[male_data['ind-entrepeneur_exp'] == False]['decision'].mean()

ent_exp_yes_female = female_data[female_data['ind-entrepeneur_exp'] == True]['decision'].mean()
ent_exp_no_female = female_data[female_data['ind-entrepeneur_exp'] == False]['decision'].mean()

# Data for plotting
labels = ['Entrepreneurial Experience', 'No Entrepreneurial Experience']
male_acceptance_rates = [ent_exp_yes_male, ent_exp_no_male]
female_acceptance_rates = [ent_exp_yes_female, ent_exp_no_female]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, male_acceptance_rates, width, label='Male', color='blue')
rects2 = ax.bar(x + width/2, female_acceptance_rates, width, label='Female', color='pink')

# Add some text for labels, title, and custom x-axis tick labels, etc.
ax.set_ylabel('Acceptance Rate')
ax.set_title('Acceptance Rate by Entrepreneurial Experience and Gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

ax.set_ylim(0, 1.0)  # Ensuring the y-axis starts at 0 and ends at 1 for clarity

plt.show()

# %%
hr_data = pd.read_csv('hr_data/HR DATA.txt', sep='\t', parse_dates=True)
hr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3310 entries, 0 to 3309
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               3310 non-null   object
#  1   EmpID                       3310 non-null   int64
#  2   MarriedID                   3310 non-null   int64
#  3   MaritalStatusID             3310 non-null   int64
#  4   GenderID                    3310 non-null   int64
#  5   EmpStatusID                 3310 non-null   int64
#  6   DeptID                      3310 non-null   int64
#  7   PerfScoreID                 3310 non-null   int64
#  8   FromDiversityJobFairID      3310 non-null   int64
#  9   PayRate                     3310 non-null   float64
#  10  Termd                       3310 non-null   int64
#  11  PositionID                  3310 non-null   int64
#  12  Position                    3310 non-null   object
# ...

# %%
active_emp = hr_data[hr_data['EmploymentStatus']=='Active']

# %%
race = active_emp[['Employee_Name', 'RaceDesc']]

# %%
race
# Out:
#            Employee_Name                   RaceDesc
# 0        Gonzalez, Maria                      White
# 1          Cockel, James                      White
# 3           Buck, Edward                      White
# 4       Jacobi, Hannah                        White
# 5       Riordan, Michael                      White
# ...                  ...                        ...
# 3305      Farrell, Karla                      Asian
# 3306   Meadows, Anderson                      White
# 3307        Braun, Jacey                      White
# 3308       Kline, Nathan  Black or African American
# 3309  Benitez, Gabriella  Black or African American
#
# [1984 rows x 2 columns]

# %%
race_counts = race['RaceDesc'].value_counts()
race_counts.plot(kind='bar', color='skyblue')
plt.title('Race Distribution')
plt.xlabel('Race')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 70k+ Job Applicants Data
# https://www.kaggle.com/datasets/ayushtankha/70k-job-applicants-data-human-resource/data

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, auc
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score

# %%
from sklearn.preprocessing import MinMaxScaler
def process_dfs(df_train_x, df_test_x, categ_cols):
    '''
    Pre-process the features of the training set and the test set, not including the outcome column.
    Convert categorical features (nominal & ordinal features) to one-hot encodings.
    Normalize the numerical features into [0, 1].
    We process training set and the test set together in order to make sure that 
    the encodings are consistent between them.
    For example, if one class is encoded as 001 and another class is encoded as 010 in the training set,
    you should follow this mapping for the test set too.
    
    :df_train: the dataframe of the training data
    :df_test: the dataframe of the test data
    :categ_cols: the column names of the categorical features. the rest features are treated as numerical ones.
    :return: the processed training data and test data, both should be numpy arrays, instead of DataFrames
    '''
    scaler = MinMaxScaler()
    df = pd.concat([df_train_x, df_test_x]) #concatenate two dataframes together in case of normalizing the numerical data
    for col in df.columns:
        if col not in categ_cols:
            df[col] = scaler.fit_transform(df[col].array.reshape(-1, 1)) #normalize the numerical columns

        else:
            df = pd.get_dummies(df,dtype=int) #convert categorical features to one-hot encodings
    train_rows = df_train_x.shape[0]
    #divide the dataframe into train and test data
    train_data_x = df.iloc[:train_rows, :].to_numpy() 
    test_data_x = df.iloc[train_rows:, :].to_numpy() 

    # TODO. 15pts
    return train_data_x, test_data_x

def stat_parity(preds, sens):
    '''
    :preds: numpy array of the model predictions. Consisting of 0s and 1s
    :sens: numpy array of the sensitive features. Consisting of 0s and 1s
    :return: the statistical parity. no need to take the absolute value
    '''
    pred_sens0 = preds[sens==0] #return the model prediction of male
    pred_sens1 = preds[sens==1] #return the model prediction of female
    prab_min = np.sum(pred_sens0)/len(pred_sens0) #probability of minority groups(male) with prediction=1(income>50k) 
    prab_max = np.sum(pred_sens1)/len(pred_sens1) #probability of majority groups(female) with prediction=1(income>50k)
    stat_parity = prab_min - prab_max
    # TODO. 7.5pts

    return stat_parity


def eq_oppo(preds, sens, labels):
    '''
    :preds: numpy array of the model predictions. Consisting of 0s and 1s
    :sens: numpy array of the sensitive features. Consisting of 0s and 1s
    :labels: numpy array of the ground truth labels of the outcome. Consisting of 0s and 1s
    :return: the statistical parity. no need to take the absolute value
    '''
    true_pos_sens0 = (labels==1)&(sens==0) #return boolean array which satisfy two conditions, Y-hat =1 and sens=0
    true_pos_sens1 = (labels==1)&(sens==1) #return boolean array which satisfy two conditions, Y-hat =1 and sens=1
    if np.sum(true_pos_sens0) != 0: 
        prob_min = np.sum(preds[true_pos_sens0])/np.sum(true_pos_sens0)
    else: #the denominator cannot be 0, if it's 0, return 0
        prob_min = 0
    if np.sum(true_pos_sens1) != 0:
        prob_max = np.sum(preds[true_pos_sens1])/np.sum(true_pos_sens1)
    else: #the denominator cannot be 0, if it's 0, return 0
        prob_max = 0
    EOD = prob_min-prob_max
    # TODO. 7.5pts
    return EOD

# %%
job_applicants = pd.read_csv('stackoverflow_full.csv')
job_applicants.drop(columns = 'Unnamed: 0', inplace=True)
missing_values = job_applicants.isna().sum()
job_applicants.drop(columns = 'HaveWorkedWith', inplace=True)
def segment_country(country):
    if country in ['United States of America', 'Canada', 'Mexico']:
        return 'NorthAmerica'
    elif country in ['United Kingdom of Great Britain and Northern Ireland', 'France', 'Germany', 'Spain', 'Italy', 'Portugal', 'Belgium', 'Netherlands', 'Austria', 'Switzerland', 'Denmark', 'Ireland', 'Norway', 'Sweden', 'Finland', 'Greece', 'Czech Republic', 'Slovakia', 'Hungary', 'Poland']:
        return 'Europe'
    elif country in ['Brazil', 'Argentina', 'Chile', 'Colombia', 'Peru', 'Venezuela, Bolivarian Republic of...', 'Bolivia']:
        return 'South America'
    elif country in ['China', 'Japan', 'South Korea', 'Viet Nam', 'India', 'Sri Lanka', 'Pakistan', 'Bangladesh', 'Indonesia', 'Malaysia', 'Philippines', 'Taiwan', 'Thailand', 'Cambodia', 'Myanmar', 'Laos', 'Singapore', 'Hong Kong (S.A.R.)']:
        return 'Asia'
    elif country in ['Australia', 'New Zealand', 'Fiji', 'Papua New Guinea', 'Solomon Islands', 'Vanuatu', 'Samoa', 'Tonga']:
        return 'Australia'
    else:
        return 'Others' 

# create a new column 'Continent'
job_applicants['Continent'] = job_applicants['Country'].apply(segment_country)
job_applicants.drop(columns = 'Country', inplace=True)
job_applicants.drop(columns = 'YearsCodePro', inplace=True)

job_applicants = job_applicants[job_applicants['Gender'] != 'NonBinary']
job_applicants['Age'] = job_applicants['Age'].map({'<35': 0, '>35': 1})
job_applicants['Gender'] = job_applicants['Gender'].map({'Man': 0, 'Woman': 1})

# %%
#Calculate Statistical parity for model with all columns
df_processed = job_applicants
#df_processed = pd.get_dummies(df)

# Prepare the features and target variables
X = df_processed.drop('Employed', axis=1)
y = df_processed['Employed']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
sens_gender = X_test['Gender'].values
sens_age = X_test['Age'].values
X_train, X_test = process_dfs(X_train, X_test, categ_cols=['EdLevel', 'Accessibility', 'MentalHealth', 'MainBranch',	'Continent'])
#preprocess train and text


dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)
y_pred_dt = dt_model.predict(X_test)


# Calculate statistical parity
acc = accuracy_score(y_test, y_pred_dt)
stat_parity_value_gender = stat_parity(y_pred_dt, sens_gender)
equal_oppo_gender = eq_oppo(y_pred_dt, sens_gender, y_test.values)

print("Accuracy: {:.4f}".format(acc))
print("Statistical Parity for Gender: {:.4f}".format(stat_parity_value_gender))
print("Equalized Opportunity for Gender: {:.4f}".format(equal_oppo_gender))

stat_parity_value_age = stat_parity(y_pred_dt, sens_age)
equal_oppo_age = eq_oppo(y_pred_dt, sens_age, y_test.values)

print("Statistical Parity for Age: {:.4f}".format(stat_parity_value_age))
print("Equalized Opportunity for Age: {:.4f}".format(equal_oppo_age))
# Out:
# Accuracy: 0.7088
# Statistical Parity for Gender: 0.1105
# Equalized Opportunity for Gender: 0.0759
# Statistical Parity for Age: 0.0270
# Equalized Opportunity for Age: 0.0071

# %% [markdown]
# ## Debiasing: 1. remove protected attribute

# %%
df_processed = job_applicants
#df_processed = pd.get_dummies(df)

# Prepare the features and target variables
X = df_processed.drop('Employed', axis=1)
y = df_processed['Employed']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
X_train_no_sens = X_train.drop(['Gender'], axis=1)
X_test_no_sens = X_test.drop(['Gender'], axis=1)

X_train, X_test = process_dfs(X_train_no_sens, X_test_no_sens, categ_cols=['EdLevel', 'Accessibility', 'MentalHealth', 'MainBranch',	'Continent'])

dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)
y_pred_dt = dt_model.predict(X_test)

# Calculate statistical parity
acc = accuracy_score(y_test, y_pred_dt)
stat_parity_value_gender_no_sens = stat_parity(y_pred_dt, sens_gender)
equal_oppo_gender_no_sens = eq_oppo(y_pred_dt, sens_gender, y_test.values)

print("Accuracy: {:.4f}".format(acc))
print("Statistical Parity for Gender without sensitive attribute: {:.4f}".format(stat_parity_value_gender_no_sens))
print("Equalized Opportunity for Gender without sensitive attribute: {:.4f}".format(equal_oppo_gender_no_sens))
# Out:
# Accuracy: 0.7088
# Statistical Parity for Gender without sensitive attribute: 0.1098
# Equalized Opportunity for Gender without sensitive attribute: 0.0542

# %% [markdown]
# ## 2. augmentin training set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

df_train_x_syn = X_train.copy()
df_train_x_syn['Gender'] = df_train_x_syn['Gender'].replace({0:1, 1:0})
df_train_y_syn = y_train.copy()

df_train_x_aug = pd.concat((X_train, df_train_x_syn))
df_train_y_aug = pd.concat((y_train, df_train_y_syn))

train_x, test_x = process_dfs(df_train_x_aug, X_test, categ_cols=['EdLevel', 'Accessibility', 'MentalHealth', 'MainBranch',	'Continent'])
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(train_x, df_train_y_aug.values)
y_pred_dt = dt_model.predict(test_x)

# Calculate statistical parity
acc = accuracy_score(y_test, y_pred_dt)
stat_parity_value_gender_aug = stat_parity(y_pred_dt, sens_gender)
equal_oppo_gender_aug = eq_oppo(y_pred_dt, sens_gender, y_test.values)

print("Accuracy: {:.4f}".format(acc))
print("Statistical Parity for Gender by augmenting: {:.4f}".format(stat_parity_value_gender_aug))
print("Equalized Opportunity for Gender by augmenting: {:.4f}".format(equal_oppo_gender_aug))
# Out:
# Accuracy: 0.7109
# Statistical Parity for Gender by augmenting: 0.1103
# Equalized Opportunity for Gender by augmenting: 0.0565

# %%
df_gender = job_applicants.drop(columns= ['Age', 'Continent'])
df_numeric = pd.get_dummies(df_gender.drop("Employed", axis=1))
df_numeric['Employed'] = df_gender['Employed']

# %%
df_male = df_numeric[job_applicants['Gender'] == 'Man']
df_female = df_numeric[job_applicants['Gender'] == 'Woman']
df_nonbinary = df_numeric[job_applicants['Gender'] == 'NonBinary']
df_female_nonbinary = pd.concat([df_female, df_nonbinary], ignore_index=True)

# Prepare the features and target variables
X_train = df_male.drop('Employed',axis=1).values
y_train = df_male['Employed'].values

X_test = df_female_nonbinary.drop('Employed', axis=1).values
y_test = df_female_nonbinary['Employed'].values

# Decision Tree Classifier
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)
y_pred_dt = dt_model.predict(X_test)

# Logistic Regression
log_reg_model = LogisticRegression(max_iter=1000, random_state=42)
log_reg_model.fit(X_train, y_train)
y_pred_log_reg = log_reg_model.predict(X_test)

# Evaluate the outcomes
dt_accuracy = accuracy_score(y_test, y_pred_dt)
log_reg_accuracy = accuracy_score(y_test, y_pred_log_reg)
print("-----------Model with gender attributes-----------------")
print("Decision Tree Accuracy (Male train, Female test):", dt_accuracy)
print("Logistic Regression Accuracy (Male train, Female test):", log_reg_accuracy)

true_decisions_dt = sum(y_pred_dt)
true_decisions_log_reg = sum(y_pred_log_reg)
print(f"Decision Tree predicted 'True' decisions: {true_decisions_dt}")
print(f"Logistic Regression predicted 'True' decisions: {true_decisions_log_reg}")


true_predictions_dt = sum(y_pred_dt)
true_predictions_log_reg = sum(y_pred_log_reg)

# Calculating the actual number of 'True' values in the test set
actual_trues = sum(y_test)

# Calculating the difference between predicted 'True' values and actual 'True' values
difference_dt = true_predictions_dt - actual_trues
difference_log_reg = true_predictions_log_reg - actual_trues

print("Difference in 'True' predictions (Decision Tree):", difference_dt)
print("Difference in 'True' predictions (Logistic Regression):", difference_log_reg)

print("-----------Model without gender attributes-----------------")

df = df_gender
# One-hot encoding for categorical variables and drop 'gender'
df_processed = pd.get_dummies(df.drop(['Gender'], axis=1))

# Prepare the features and target variables
X = df_processed.drop('Employed', axis=1).values
y = df_processed['Employed'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)
y_pred_dt = dt_model.predict(X_test)


ratio_true_dt = sum(y_pred_dt) / len(y_pred_dt)
ratio_true_log_reg = sum(y_pred_log_reg) / len(y_pred_log_reg)
actual_ratio_true = sum(y_test) / len(y_test)

# Display the ratios
print("Actual ratio of 'True' decisions:", actual_ratio_true)

print("Ratio of 'True' decisions (Decision Tree):", ratio_true_dt)
# print("Ratio of 'True' decisions (Logistic Regression):", ratio_true_log_reg)
# Out:
# -----------Model with gender attributes-----------------
# Decision Tree Accuracy (Male train, Female test): 0.7148701165882594
# Logistic Regression Accuracy (Male train, Female test): 0.6297811413376969
# Decision Tree predicted 'True' decisions: 2368
# Logistic Regression predicted 'True' decisions: 3594
# Difference in 'True' predictions (Decision Tree): 58
# Difference in 'True' predictions (Logistic Regression): 1284
# -----------Model without gender attributes-----------------
# Actual ratio of 'True' decisions: 0.5347522996328837
# Ratio of 'True' decisions (Decision Tree): 0.5406509095408984

# %%
df = df_gender
# One-hot encoding for categorical variables and drop 'gender'
df_processed = pd.get_dummies(df.drop(['Gender'], axis=1))

# Prepare the features and target variables
X = df_processed.drop('Employed', axis=1).values
y = df_processed['Employed'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)
y_pred_dt = dt_model.predict(X_test)



ratio_true_dt = sum(y_pred_dt) / len(y_pred_dt)
ratio_true_log_reg = sum(y_pred_log_reg) / len(y_pred_log_reg)
actual_ratio_true = sum(y_test) / len(y_test)

# Display the ratios
print("Actual ratio of 'True' decisions:", actual_ratio_true)

print("Ratio of 'True' decisions (Decision Tree):", ratio_true_dt)
# print("Ratio of 'True' decisions (Logistic Regression):", ratio_true_log_reg)
# Out:
# Actual ratio of 'True' decisions: 0.5347522996328837
# Ratio of 'True' decisions (Decision Tree): 0.5406509095408984

# %% [markdown]
# ### Age bias analysis

# %%
df_age = job_applicants.drop(columns= ['Gender', 'Continent'])
df_numeric_age = pd.get_dummies(df_age.drop("Employed", axis=1))
df_numeric_age['Employed'] = df_age['Employed']
df_numeric_age
# Out:
#        Employment  YearsCode  YearsCodePro  PreviousSalary  ComputerSkills  \
# 0               1          7             4         51552.0               4
# 1               1         12             5         46482.0              12
# 2               1         15             6         77290.0               7
# 3               1          9             6         46135.0              13
# 4               0         40            30        160932.0               2
# ...           ...        ...           ...             ...             ...
# 73457           1          7             2         41058.0              13
# 73458           1         21            16        115000.0              11
# 73459           1          4             3         57720.0              12
# 73460           1          5             1         70000.0              15
# 73461           1         10             3         75384.0               2
#
# ...

# %%
df_abov35 = df_numeric_age[job_applicants['Age'] == '>35']
df_bel35 = df_numeric_age[job_applicants['Age'] == '<35']

# Prepare the features and target variables
X_train = df_abov35.drop('Employed',axis=1).values
y_train = df_abov35['Employed'].values

X_test = df_bel35.drop('Employed', axis=1).values
y_test = df_bel35['Employed'].values

# Decision Tree Classifier
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)
y_pred_dt = dt_model.predict(X_test)

# Logistic Regression
log_reg_model = LogisticRegression(max_iter=1000, random_state=42)
log_reg_model.fit(X_train, y_train)
y_pred_log_reg = log_reg_model.predict(X_test)

# Evaluate the outcomes
age_dt_accuracy = accuracy_score(y_test, y_pred_dt)
age_log_reg_accuracy = accuracy_score(y_test, y_pred_log_reg)

print("Decision Tree Accuracy (>35 train, <35 test):", age_dt_accuracy)
print("Logistic Regression Accuracy (>35 train, <35 test):", age_log_reg_accuracy)

true_decisions_dt = sum(y_pred_dt)
true_decisions_log_reg = sum(y_pred_log_reg)
print(f"Decision Tree predicted 'True' decisions: {true_decisions_dt}")
print(f"Logistic Regression predicted 'True' decisions: {true_decisions_log_reg}")

true_predictions_dt = sum(y_pred_dt)
true_predictions_log_reg = sum(y_pred_log_reg)

# Calculating the actual number of 'True' values in the test set
actual_trues = sum(y_test)

# Calculating the difference between predicted 'True' values and actual 'True' values
difference_dt = true_predictions_dt - actual_trues
difference_log_reg = true_predictions_log_reg - actual_trues

print("Difference in 'True' predictions (Decision Tree):", difference_dt)
print("Difference in 'True' predictions (Logistic Regression):", difference_log_reg)
# Out:
# Decision Tree Accuracy (>35 train, <35 test): 0.6959576737280161
# Logistic Regression Accuracy (>35 train, <35 test): 0.6275748133587068
# Decision Tree predicted 'True' decisions: 26233
# Logistic Regression predicted 'True' decisions: 43263
# Difference in 'True' predictions (Decision Tree): 63
# Difference in 'True' predictions (Logistic Regression): 17093

# %%
df = df_age
# One-hot encoding for categorical variables and drop 'gender'
df_processed = pd.get_dummies(df.drop(['Age'], axis=1))

# Prepare the features and target variables
X = df_processed.drop('Employed', axis=1).values
y = df_processed['Employed'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)
y_pred_dt = dt_model.predict(X_test)


age_ratio_true_dt = sum(y_pred_dt) / len(y_pred_dt)
age_ratio_true_log_reg = sum(y_pred_log_reg) / len(y_pred_log_reg)
age_actual_ratio_true = sum(y_test) / len(y_test)

# Display the ratios
print("Actual ratio of 'True' decisions:", age_actual_ratio_true)

print("Ratio of 'True' decisions (Decision Tree):", age_ratio_true_dt)
# print("Ratio of 'True' decisions (Logistic Regression):", ratio_true_log_reg)
# Out:
# Actual ratio of 'True' decisions: 0.5347522996328837
# Ratio of 'True' decisions (Decision Tree): 0.5406509095408984

# %%
comparison_table = pd.DataFrame({
    'Model': ['Gender', 'Age'],
    'With': [round(dt_accuracy,4),  round(age_dt_accuracy,4)],
    'Without': [round(ratio_true_dt,4), round(age_ratio_true_dt,4)]
})

print(comparison_table)

fig, ax = plt.subplots(1, 1, figsize=(5, 2))  # Adjust figure size as needed
ax.axis('tight')
ax.axis('off')
ax.table(cellText=comparison_table.values,
         colLabels=comparison_table.columns,
         cellLoc = 'center', 
         loc='center')
plt.show()
# Out:
#     Model    With  Without
# 0  Gender  0.7149   0.5407
# 1     Age  0.6960   0.5407
